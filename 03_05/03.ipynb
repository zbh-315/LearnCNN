# %% [markdown]
# ## 第03天：初始Opencv，搭建图像处理模块（2）

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt



img=cv2.imread('cat.jpg')

# %% [markdown]
# ### matplotlib.pyplot plt展示图片和灰度图

# %%
img_gray1=cv2.imread('cat.jpg',0)
imgOfThree = np.concatenate((np.expand_dims(img_gray1, axis=2), np.expand_dims(img_gray1, axis=2), np.expand_dims(img_gray1, axis=2)), axis=-1)

plt.imshow(imgOfThree)

# %%
plt.imshow(img)

# %% [markdown]
# ### cv2展示图片和灰度图

# %%
def cv_show(img_name,img_path):
    cv2.imshow(img_name, img_path)
    cv2.waitKey(0)    
    cv2.destroyAllWindows()

# %%
cv_show('cat',img)
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv_show('cat_gray',img_gray)

# %%
cv2.imwrite("cat_gray.jpg",img_gray1)
# Out:
# True

# %% [markdown]
# ## 视频操作
# 略

# %% [markdown]
# ## 图像基本操作

# %%
img=cv2.imread('cat.jpg')
img1=img[0:100,0:200]
cv_show('cat',img1)
## 取部分

# %%
#取rgb
imgR=img.copy()
imgR[:,:,0:2]=0
cv_show('R',imgR)
plt.imshow(imgR)

imgG=img.copy()
imgG[:,:,0]=0
imgG[:,:,2]=0
cv_show('R',imgG)

imgB=img.copy()
imgB[:,:,1:3]=0
cv_show('B',imgB)

# %% [markdown]
# ### 边界填充

# %%
k_size=150
top_size,bottom_size,left_size,right_size = (k_size,k_size,k_size,k_size)

replicate = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, cv2.BORDER_WRAP)
constant = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size,cv2.BORDER_CONSTANT, value=0)


import matplotlib.pyplot as plt
plt.subplot(231), plt.imshow(img, 'gray'), plt.title('ORIGINAL')
plt.subplot(232), plt.imshow(replicate, 'gray'), plt.title('REPLICATE')
plt.subplot(233), plt.imshow(reflect, 'gray'), plt.title('REFLECT')
plt.subplot(234), plt.imshow(reflect101, 'gray'), plt.title('REFLECT_101')
plt.subplot(235), plt.imshow(wrap, 'gray'), plt.title('WRAP')
plt.subplot(236), plt.imshow(constant, 'gray'), plt.title('CONSTANT')

plt.show()

# %% [markdown]
# - BORDER_REPLICATE：复制法，也就是复制最边缘像素。
# - BORDER_REFLECT：反射法，对感兴趣的图像中的像素在两边进行复制例如：fedcba|abcdefgh|hgfedcb
# - BORDER_REFLECT_101：反射法，也就是以最边缘像素为轴，对称，gfedcb|abcdefgh|gfedcba
# - BORDER_WRAP：外包装法cdefgh|abcdefgh|abcdefg
# - BORDER_CONSTANT：常量法，常数值填充。

# %% [markdown]
# ### 数值计算

# %%
img_cat=cv2.imread('cat.jpg')
img_cat2=img_cat
plt.subplot(231), plt.imshow(img_cat), plt.title('img_cat')
plt.subplot(232), plt.imshow(img_cat2), plt.title('img_cat2')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x29b831f14a8>,
# ...
#  Text(0.5,1,'img_cat2'))

# %%
img_cat3=img_cat+img_cat
cv_show('img_cat3',img_cat3)
cv_show('img_cat3',cv2.add(img_cat,img_cat))

# %%
img_cat=cv2.imread('cat.jpg')
img_dog=cv2.imread('dog.jpg')
plt.subplot(231), plt.imshow(img_dog), plt.title('img_dog')
img_dog=cv2.resize(img_dog,(img_cat.shape[1],img_cat.shape[0]))
plt.subplot(232), plt.imshow(img_dog2), plt.title('img_dog2')
plt.subplot(233), plt.imshow(img_cat), plt.title('img_cat')

cat_dog=cv2.addWeighted(img_cat,0.5,img_dog,0.6,3)

plt.subplot(234), plt.imshow(cat_dog), plt.title('cat_dog')

# %% [markdown]
# ### test:my_show

# %%
def cv_show(*img_path):
    res = np.hstack(img_path)
    cv2.imshow('img', res)
    cv2.waitKey(0)    
    cv2.destroyAllWindows() 
def plt_show(*args):
    for i in range(len(args)):
        plt.subplot(231+i), plt.imshow(args[i])

# %%
img1=cv2.imread('test.png')
img2=cv2.add(img1,img1)
cv_show(img1,img2)
plt_show(img1,img2)
